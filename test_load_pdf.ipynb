# %%
import camelot

tabel = camelot.read_pdf('PNPK 2023 GGK tabel.pdf')

# %%
tabel[0].parsing_report
# Out:
# {'accuracy': 100.0, 'whitespace': 3.7, 'order': 1, 'page': 1}

# %%
tabel[0].df
# Out:
#                                                    0  \
# 0
# 1                                     Akses vaskular
# 2                     Akses laju aliran darah \n(Qb)
# 3                               Laju aliran dialisat
# 4                                  Laju aliran infus
# 5                                        Durasi sesi
# 6  Volume konvektif \n(volume pengganti + \npenur...
# 7  Persen volume \nkonvektif dari volume \ndarah ...
# 8                                           Dialiser
#
#                                                    1  \
# 0                                         Preskripsi
# 1  Fistula arteriovenosa \natau cangkok kateter \...
# 2                                 350 – 500 ml/menit
# 3           400 – 500 ml/menit + \nlaju aliran infus
# 4                25 – 33% of Qb, \n90 – 160 ml/menit
# 5                                     4 – 5 jam/sesi
# 6                                         >23 L/sesi
# 7                                           25 – 30%
# 8                               Membran fluks tinggi
#
#                                                    2
# 0                                        Rekomendasi
# 1                Opsi pertama \nmenambah durasi sesi
# 2                                 Semaksimal mungkin
# 3          Tidak ada pengaruh \npada dosis konvektif
# 4                                 Semaksimal mungkin
# 5                                 Semaksimal mungkin
# 6                                 Semaksimal mungkin
# 7                                 Semaksimal mungkin
# 8  Koefisien ultrafiltrasi \n>20ml/jam/mmHg/m2;  ...

# %%
camelot.plot(tabel[0], kind='contour').show()
# Out:
# D:\temp\ipykernel_17344\2112991977.py:1: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   camelot.plot(pdf[0], kind='contour').show()
