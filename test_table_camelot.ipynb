# %%
import camelot

tabel = camelot.read_pdf('data/pdfs/Tatalaksana_Penyakit_Ginjal_Kronik_pada_Anak.pdf', pages='5')

# %%
tabel[0].parsing_report
# Out:
# {'accuracy': 95.4, 'whitespace': 38.0, 'order': 1, 'page': 5}

# %%
camelot.plot(tabel[0], kind='line').show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 camelot.plot(tabel[0], kind='line').show()
#
# File d:\Python\lib\site-packages\camelot\core.py:689, in TableList.__getitem__(self, idx)
#     688 def __getitem__(self, idx):
# --> 689     return self._tables[idx]
#
# IndexError: list index out of range

# %%
clean_tabel = tabel[0].df
clean_tabel
# clean_tabel.columns = clean_tabel.iloc[0]

# # Drop the first row to avoid duplication in headers
# clean_tabel = clean_tabel.drop(0)

# test = clean_tabel.reset_index(drop=True)
# test
# Out:
#                  0                                                  1  \
# 0                                                    Bayi (0-1 tahun)
# 1           Energi  0-0,5 \ntahun: \n≥ \n108 \nkkal/kg BB \n0,5-1 ...
# 2          Protein  0-0,5 \ntahun:  2,2  g/kg \nBB \n0,5-1 \ntahun...
# 3          Natrium  Umumnya \ntidak  direstriksi;  1-3  mEq/kg  BB...
# 4           Kalium  1-3 mEq/kg BB jika diperlukan (biasa tidak dir...
# 5          Kalsium  0-0,5 tahun:400 mg/hari \n800 mg/hari  \n800 m...
# 6                   *(jika hiperkalsemia tidak terjadi dan produk ...
# 7           Fosfor  Gunakan \nformula \nrendah fosfor jika kadar \...
# 8          Vitamin  Multivitamin  jika  diperlukan;  metabolit  vi...
# 9  Mineral \nmikro  Suplemen zink, besi, atau tembaga jika diperlukan
#
#                                                    2  \
# 0                                 Batita (1-3 tahun)
# 1                                     102 kkal/kg BB
# ...

# %%
clean_tabel.to_html().replace("\n", "")
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>0</th>      <th>1</th>      <th>2</th>      <th>3</th>      <th>4</th>    </tr>  </thead>  <tbody>    <tr>      <th>0</th>      <td></td>      <td>Bayi (0-1 tahun)</td>      <td>Batita (1-3 tahun)</td>      <td>Anak (3-10 tahun)</td>      <td>Remaja (11-18 tahun)</td>    </tr>    <tr>      <th>1</th>      <td>Energi</td>      <td>0-0,5 \\ntahun: \\n≥ \\n108 \\nkkal/kg BB \\n0,5-1 \\ntahun:  ≥  kkal/kg \\nBB</td>      <td>102 kkal/kg BB</td>      <td>4-6 \\ntahun:  90  kkal/kg \\nBB \\n7-10  tahun:  70  kkal/kg \\nBB</td>      <td>P:11-14 tahun:47 kkal/kg BB \\nP:15-18 tahun:40 kkal/kg BB \\nL:11-14 tahun:55 kkal/kg BB \\nL:15-18 tahun:45 kkal/kg BB</td>    </tr>    <tr>      <th>2</th>      <td>Protein</td>      <td>0-0,5 \\ntahun:  2,2  g/kg \\nBB \\n0,5-1 \\ntahun:  1,6  g/kg \\nBB</td>      <td>1,2 g/kg BB</td>      <td>4-6 tahun: 1,2 g/kg BB \\n7-10 tahun: 1,0 g/kg BB</td>   
# ...

# %%
camelot.plot(tabel[0], kind='contour').show()
# Out:
# D:\temp\ipykernel_17692\4004047960.py:1: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   camelot.plot(tabel[0], kind='contour').show()
